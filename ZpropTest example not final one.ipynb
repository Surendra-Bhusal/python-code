# %% [markdown]
# <a href="https://colab.research.google.com/github/Surendra-Bhusal/python-code/blob/main/ZpropTest%20example%20not%20final%20one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
list1 = []

# %%
for i in range (0,50000):
  list1.append (i)

# %%
len(list1)
# Out:
# 50000

# %%
list2= []

# %%
for i in range(0,45000):
  list2.append('Yes')

# %%
for i in range (0,5000):
  list2. append('No')

# %%
pd.Series(list1)
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 49995    49995
# 49996    49996
# 49997    49997
# 49998    49998
# 49999    49999
# Length: 50000, dtype: int64

# %%
df=  pd.DataFrame(pd.Series(list1))

# %%
df
# Out:
#            0
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 49995  49995
# 49996  49996
# 49997  49997
# 49998  49998
# 49999  49999
#
# [50000 rows x 1 columns]

# %%
df['Receives aspirin']= pd.Series(list2)

# %%
df
# Out:
#            0 Receives aspirin
# 0          0              Yes
# 1          1              Yes
# 2          2              Yes
# 3          3              Yes
# 4          4              Yes
# ...      ...              ...
# 49995  49995               No
# 49996  49996               No
# 49997  49997               No
# 49998  49998               No
# 49999  49999               No
#
# [50000 rows x 2 columns]

# %%
df.columns
# Out:
# Index([0, 'Receives aspirin'], dtype='object')

# %%
df = df.rename(columns={0: 'Patient_ID'})

# %%
df
# Out:
#        Patient_ID Receives aspirin  Random_Number
# 0               0              Yes           6644
# 1               1              Yes           1910
# 2               2              Yes           7933
# 3               3              Yes            648
# 4               4              Yes           8643
# ...           ...              ...            ...
# 49995       49995               No            669
# 49996       49996               No           7265
# 49997       49997               No           1973
# 49998       49998               No           2639
# 49999       49999               No           6580
#
# [50000 rows x 3 columns]

# %%
import numpy as np

# %%
df['Random_Number'] = np.random.randint(1, 10000, size=len(df))

# %%
df = df.sort_values(by='Random_Number')

# %%
df['Receives aspirin'].value_counts()
# Out:
# Receives aspirin
# Yes    45000
# No      5000
# Name: count, dtype: int64

# %%
df= df.drop(columns= {'Random_Number'})

# %%
df.reset_index(inplace=True)

# %%
df= df.drop(columns= {'index'})

# %%
df
# Out:
#        Patient_ID Receives aspirin
# 0           20858              Yes
# 1           38133              Yes
# 2            7966              Yes
# 3           32920              Yes
# 4           35363              Yes
# ...           ...              ...
# 49995       17364              Yes
# 49996       16529              Yes
# 49997       16291              Yes
# 49998       44308              Yes
# 49999       17741              Yes
#
# [50000 rows x 2 columns]

# %%
df.to_excel(r'/content/sample_data/zPropTest.xlsx')

# %%
df= pd.read_excel(r'/content/sample_data/zPropTest.xlsx')

# %%
df['Patient_Id'] = pd.Series(list1)

# %%
df
# Out:
#        Unnamed: 0  Patient_ID Receives aspirin  Patient_Id
# 0               0       20858              Yes           0
# 1               1       38133              Yes           1
# 2               2        7966              Yes           2
# 3               3       32920              Yes           3
# 4               4       35363              Yes           4
# ...           ...         ...              ...         ...
# 49995       49995       17364              Yes       49995
# 49996       49996       16529              Yes       49996
# 49997       49997       16291              Yes       49997
# 49998       49998       44308              Yes       49998
# 49999       49999       17741              Yes       49999
#
# [50000 rows x 4 columns]

# %%
df = df.drop(columns={'Patient_ID'})

# %%
df
# Out:
#        Unnamed: 0 Receives aspirin  Patient_Id
# 0               0              Yes           0
# 1               1              Yes           1
# 2               2              Yes           2
# 3               3              Yes           3
# 4               4              Yes           4
# ...           ...              ...         ...
# 49995       49995              Yes       49995
# 49996       49996              Yes       49996
# 49997       49997              Yes       49997
# 49998       49998              Yes       49998
# 49999       49999              Yes       49999
#
# [50000 rows x 3 columns]

# %%
df= df[['Patient_Id', 'Receives aspirin']]

# %%
list1= []
for i in range (0,100):
    new_df = df.sample(n=100)
    z= (((new_df[new_df['Receives aspirin']=='Yes'].shape[0])/100)- 0.90 )/MOE
    list1.append(z)

# %%
list1
# Out:
# [0.0,
#  -1.0000000000000009,
#  -2.0000000000000018,
#  0.6666666666666672,
#  -1.3333333333333344,
#  -0.6666666666666672,
#  -1.666666666666668,
#  -0.3333333333333336,
#  -0.3333333333333336,
#  0.3333333333333336,
#  -0.3333333333333336,
#  -1.0000000000000009,
#  -0.3333333333333336,
#  1.0000000000000009,
#  0.6666666666666672,
#  -0.3333333333333336,
#  0.0,
#  -0.3333333333333336,
#  -0.6666666666666672,
#  -1.666666666666668,
#  -0.3333333333333336,
#  0.6666666666666672,
#  0.3333333333333336,
#  1.999999999999998,
#  0.0,
#  -0.3333333333333336,
#  -0.6666666666666672,
#  -0.3333333333333336,
#  1.0000000000000009,
#  0.0,
#  1.3333333333333308,
#  -1.0000000000000009,
#  0.6666666666666672,
#  0.3333333333333336,
#  -0.6666666666666672,
#  -0.3333333333333336,
#  0.3333333333333336,
#  -1.3333333333333344,
#  1.6666666666666643,
#  0.3333333333333336,
#  0.6666666666666672,
#  -0.6666666666666672,
#  0.6666666666666672,
#  0.6666666666666672,
#  0.0,
# ...

# %%
# prompt: plot the values from list1 as histogram

import matplotlib.pyplot as plt

plt.hist(list1)
plt.xlabel('Z-scores')
plt.ylabel('Frequency')
plt.title('Histogram of Z-scores')
plt.show()

# %%
list2= []
for i in range (0,1000):
    new_df = df.sample(n=100)
    z= (((new_df[new_df['Receives aspirin']=='Yes'].shape[0])/100)- 0.90 )/MOE
    list2.append(z)

# %%
import matplotlib.pyplot as plt

plt.hist(list2)
plt.xlabel('Z-scores')
plt.ylabel('Frequency')
plt.title('Histogram of Z-scores')
plt.show()

# %%
list3= []
for i in range (0,10000):
    new_df = df.sample(n=100)
    z= (((new_df[new_df['Receives aspirin']=='Yes'].shape[0])/100)- 0.90 )/MOE
    list3.append(z)

# %%
plt.hist(list3)
plt.xlabel('Z-scores')
plt.ylabel('Frequency')
plt.title('Histogram of Z-scores')
plt.show()

# %%
len(list3)
# Out:
# 10000

# %%
# prompt: calculate the proportion of numbers between -1.96 and +1.96 in list 3

import numpy as np

# Assuming list3 is defined in the previous code
proportion = np.sum((np.array(list3) >= -1.96) & (np.array(list3) <= 1.96)) / len(list3)
proportion
# Out:
# 0.9379

# %%
len(new_df ['Patient_Id'].unique())
# Out:
# 100

# %%
MOE= np.sqrt((0.9*0.1)/100)

# %%
MOE
# Out:
# 0.030000000000000002

# %%
(((new_df[new_df['Receives aspirin']=='Yes'].shape[0])/100)- 0.90 )/MOE
# Out:
# -0.6666666666666672

# %%
new_df1 = df.sample(n=100)

# %%
new_df1
# Out:
#        Patient_Id Receives aspirin
# 7723         7723              Yes
# 22593       22593              Yes
# 41671       41671              Yes
# 44054       44054              Yes
# 5085         5085              Yes
# ...           ...              ...
# 11351       11351              Yes
# 27813       27813              Yes
# 16173       16173              Yes
# 35467       35467              Yes
# 48116       48116              Yes
#
# [100 rows x 2 columns]

# %%
len(new_df1 ['Patient_Id'].unique())
# Out:
# 100
